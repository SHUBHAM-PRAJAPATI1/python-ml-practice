# %%
#1.import numpy
import numpy as np

# %%
#2.print version and configuration
print(np.__version__)
np.show_config()

# %%
#3.create a null vector of size 10
s = np.zeros(10)
print(s)

# %%
#4.how to find the memory size of any array
s = np.zeros((10,10))
print("%d bytes"%(s.size * s.itemsize))

# %%
#5.how to get  the documention of the numpy add function from the command line?
# !python -c "import numpy; numpy.info(numpy.add)"

# %%
#6.create a null vector of size 10 but the fifth value which is 1
s = np.zeros(10)
s[4]=1
print(s)

# %%
#7.create a vector with value ranging from 10 to 49
s=np.arange(10,50)
print(s)

# %%
#8.reverse a vector
z = np.arange(50)
z = z[::-1]

print(z)

# %%
#9.create a 3x3 matrix with values ranging from 0 to 8
s = np.arange(9).reshape(3,3)
print(s)

# %%
#10.find the indices of non zero elements from[ 1,2,0,0,4,0]
s =  np.nonzero([1,2,0,0,4,0])
print(s)

# %%
import numpy as np

# %%
#11.find a 3x3 identity matrix 
s = np.eye(3)
print(s)

# %%
#12.create a 3x3x3 array random value
s = np.random.random((3,3,3))
print(s)

# %%
#13.create a 10x10 array with random values and find the minimum and maximum values
s= np.random.random((10,10))
print(s)
smin ,smax = s.min(), s.max()
print(smin, smax)

# %%
#14.create a random vector of size 30 and find the mean value
s = np.random.random(30)
smean = s.mean()
print(s)
print(smean)

# %%
#15.Create a 2d array with 1 on the border and 0 inside
s = np.ones((10,10))
s[1:-1,1:-1] = 0
print(s)

# %%
#16.how to add a border around an existing array
z = np.ones((5,5))
z = np.pad(z, pad_width=1,mode='constant',constant_values=0)
print(z)

# %%
#17. result of the following expression
0*np.nan
np.nan==np.nan
np.inf > np.nan
np.nan - np.nan
np.nan in set([np.nan])
0.3==3*0.1

print(0*np.nan)
print(np.nan==np.nan)
print(np.inf>np.nan)
print(np.nan-np.nan)
print(np.nan in set([np.nan]))
print(0.3 == 3*0.1)


#nan
#False
#False
#nan
#True
#False

# %%
#18.create a 5x5 matrix with values 1,2,3,4 just below the diagonal
s=np.diag(1+np.arange(4),k=-1)
print(s)

# %%
#19.create a 8x8 matrix and fill it with a checkboard pattern
s=np.zeros((8,8),dtype=int)
s[1::2,::2]=1
s[::2,1::2]=1
print(s)

# %%
#20. consider a (6,7,8)shape array , what is the index(x,y,z) of the 100th element?
print(np.unravel_index(99,(6,7,8)))

# %%
import numpy as np

# %%
#21.create a 8x8 matrix using the tile function
s=np.tile(np.array([[0,1],[1,0]]),(4,4))
print(s)

# %%
#22.normalize a 5x5 random matrix
s = np.random.random((5,5))
s = (s-np.mean(s))/(np.std(s))
print(s)

# %%
#23. create a custom dtype that describes a color as four unsigned bytes (RGBA)
color = np.dtype([("r",np.ubyte),
                  ("g",np.ubyte),
                  ("b",np.ubyte),
                  ("a",np.ubyte)])
print(color)

# %%
#24. multiply a 5x3 matrix  by a 3x2 matrix 
z = np.matmul(np.ones((5,3)),np.ones((3,2)))
print(z)

# %%
import numpy as np

# %%
#25.given a 1D array , negate all elements which are between 3 and 8 , in place

s = np.arange(9)
s[(3<s)&(s<8)]*=-1

print(s)

# %%
#26.what is the output of the following script?
print(sum(range(5),-1))
from numpy import*
print(sum(range(5),-1))

#9
#10

# %%
#27.consider an integer vector Z, which of these are legal?
Z**Z            #legal
2<<Z>>2         #legal
Z<-Z            #not legal
1j*z            #legal
Z/1/1           #legal
Z<z>z           #legal

# %%
#28. what are the result of the following expressions?
np.array(0) / np.array(0)#undefined
np.array(0) // np.array(0)#undefined
np.array([np.nan]).astype(int).astype(float)#defined

# %%
#29. How to round away from zero a float array ? 
s= np.random.uniform(-10,+10,10)
print(np.copysign(np.ceil(np.abs(s)),s))

print(np.where(s>0,np.ceil(s),np.floor(s)))

# %%
#30 how to find common values between two arrays?
Z1 = np.random.randint(0,10,10)
Z2 = np.random.randint(0,10,10)
print(np.intersect1d(Z1,Z2))
